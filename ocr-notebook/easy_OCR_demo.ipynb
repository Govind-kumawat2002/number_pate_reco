# %%
! pip install easyocr

# The EasyOCR library is used for Optical Character Recognition (OCR). It allows you to extract text from images or scanned documents. The main features and use cases of the library are:
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# ...
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 11.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    - -------------------------------------- 8.4/204.1 MB 39.9 MB/s eta 0:00:05
#    --- ------------------------------------ 18.4/204.1 MB 43.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 28.3/204.1 MB 44.2 MB/s eta 0:00:04
#    ------- -------------------------------- 38.0/204.1 MB 44.3 MB/s eta 0:00:04
# ...

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
# from IPython.display import Image 
from PIL import Image

## The PIL (Python Imaging Library), now known as Pillow (a modern fork), is a library used for image processing tasks in Python. It provides functionalities for opening, manipulating, and saving various image file formats.

# %%
Image.open(r"C:\Users\kumaw\OneDrive\Desktop\Number_plate_recog\Number_plate_recog\number_pate_reco\plates\Figure_1.png")


# open thev image a  particular path
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %%
reader = easyocr.Reader(['en']) # read the content by reader function
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
output = reader.readtext(r'C:\Users\kumaw\OneDrive\Desktop\Number_plate_recog\Number_plate_recog\number_pate_reco\plates\Figure_1.png',detail=0)


## read the text from image by using readtext function

# %%
output
# Out:
# ['Result',
#  '100',
#  '200',
#  'SUDOKU',
#  'PUZND',
#  '300',
#  '400',
#  '5  8',
#  '49',
#  '100',
#  '200',
#  '300',
#  '400',
#  '500',
#  '600']

# %%
cord = output[-1][0]

# %%
cord
# Out:
# '6'

# %%
a = list(zip(*cord))
a
# Out:
# [('1',)]

# %%
min(a[0])
# Out:
# '1'

# %%
# min(a[1])

# %%
max(a[0])
# Out:
# '1'

# %%
max(a[0])
# Out:
# '1'

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
#
# Cell In[23], line 1, in <listcomp>(.0)
# ----> 1 x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
#
# ValueError: invalid literal for int() with base 10: 'U'

# %%
x_min, y_min
# Out:
# (307, 249)

# %%
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
x_max, y_max
# Out:
# (339, 263)

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 30

# %%
image = cv2.imread('/content/bottle.jpg')
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
